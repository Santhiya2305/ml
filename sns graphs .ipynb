# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
tips=sns.load_dataset('tips')
sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title('Scatter Plot of Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
tips=sns.load_dataset('tips')
sns.lineplot(x='total_bill',y='tip',data=tips)
plt.title('line Plot of Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
tips=sns.load_dataset('tips')
sns.boxplot(x='total_bill',y='tip',data=tips)
plt.title('box Plot of Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
tips=sns.load_dataset('tips')
sns.barplot(x='total_bill',y='tip',data=tips)
plt.title('bar Plot of Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
tips=sns.load_dataset('tips')
sns.lmplot(x='total_bill',y='tip',data=tips)
plt.title('lm Plot of Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
tips=sns.load_dataset('tips')
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')
plt.title('joint Plot of Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
tips=sns.load_dataset('tips')
sns.violinplot(x='total_bill',y='tip',data=tips)
plt.title(' violin Plot of Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
iris=sns.load_dataset('iris')
numerical_iris = iris.drop('species', axis=1)
correlation_matrix=numerical_iris.corr()
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
tips=sns.load_dataset('tips')
sns.pairplot(tips)
plt.title(' pairPlot of Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()
